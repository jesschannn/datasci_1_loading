# %% [markdown]
# <a href="https://colab.research.google.com/github/jesschannn/datasci_1_loading/blob/main/datasci_1_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import plotly as plt

# %% [markdown]
# # CSV Datasets

# %%
import pandas as pd

# %% [markdown]
# ## CSV Dataset 1

# %%
csv_df1 = pd.read_csv("Monkeypox_Research_Summary_Data.csv")
csv_df1
# Out:
#                                     Research Activity  \
# 0                        Vaccine Immunogenicity Study
# 1              Vaccine Immunogenicity Study (Vaccine)
# 2                      Drug-Vaccine Interaction Study
# 3                         Vaccine Effectiveness Study
# 4        Vaccine Effectiveness Case Series Evaluation
# ..                                                ...
# 66       Serosurveys and Improved Serological Surveys
# 67                              Biosurveillance study
# 68                             Education and Training
# 69  International Training and equipment upgrades/...
# 70  Computational and Bioinformatics support; Outr...
#
#    Project Title \n(and link to additional information, if available)  \
# 0   A Multicenter Trial Evaluating Alterative Dosi...
# 1   A Multicenter Trial Evaluating Alterative Dosi...
# 2   Study to evaluate the immunogenicity profile a...
# 3   National estimates of post-licensure vaccine p...
# ...

# %%
csv_result1 = csv_df1.head(10)
print("First 10 rows of the DataFrame:")
csv_result1
# Out:
# First 10 rows of the DataFrame:
#                               Research Activity  \
# 0                  Vaccine Immunogenicity Study
# 1        Vaccine Immunogenicity Study (Vaccine)
# 2                Drug-Vaccine Interaction Study
# 3                   Vaccine Effectiveness Study
# 4  Vaccine Effectiveness Case Series Evaluation
# 5                     Vaccine Utilization Study
# 6                   Vaccine Safety Surveillance
# 7                  Vaccine Immunogenicity Study
# 8                      Novel Vaccine Evaluation
# 9              Next Generation Vaccine Research
#
#   Project Title \n(and link to additional information, if available)    Topic  \
# 0  A Multicenter Trial Evaluating Alterative Dosi...                  Vaccine
# 1  A Multicenter Trial Evaluating Alterative Dosi...                  Vaccine
# 2  Study to evaluate the immunogenicity profile a...                  Vaccine
# 3  National estimates of post-licensure vaccine p...                  Vaccine
# ...

# %% [markdown]
# ## CSV Dataset 2

# %%
csv_df2 = pd.read_csv("NYPD_Hate_Crimes.csv")
csv_df2
# Out:
#       Full Complaint ID  Complaint Year Number  Month Number  \
# 0       201904612204817                   2019             2
# 1       201904812229517                   2019             3
# 2       201904812231317                   2019             3
# 3       201904812226617                   2019             3
# 4       201904212405517                   2019             5
# ...                 ...                    ...           ...
# 2242    202310312423517                   2023             4
# 2243    202310312621817                   2023             5
# 2244    202311412151817                   2023             1
# 2245    202312212203117                   2023             3
# 2246    202312212278017                   2023             4
#
#      Record Create Date  Complaint Precinct Code        Patrol Borough Name  \
# 0            02/08/2019                       46          PATROL BORO BRONX
# 1            03/09/2019                       48          PATROL BORO BRONX
# ...

# %%
csv_result2 = csv_df2.head(10)
print("First 10 rows of the DataFrame:")
csv_result2
# Out:
# First 10 rows of the DataFrame:
#    Full Complaint ID  Complaint Year Number  Month Number Record Create Date  \
# 0    201904612204817                   2019             2         02/08/2019
# 1    201904812229517                   2019             3         03/09/2019
# 2    201904812231317                   2019             3         03/10/2019
# 3    201904812226617                   2019             3         03/08/2019
# 4    201904212405517                   2019             5         05/11/2019
# 5    201904212405517                   2019             5         05/11/2019
# 6    201904212405517                   2019             5         05/11/2019
# 7    201904012711317                   2019             6         06/01/2019
# 8    201904912495217                   2019             7         07/09/2019
# 9    201904712851617                   2019             8         08/05/2019
#
#    Complaint Precinct Code Patrol Borough Name County  \
# ...

# %% [markdown]
# ## CSV Dataset 3

# %%
csv_df3 = pd.read_csv("Meteorite_Landings.csv")
csv_df3
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation
# ...

# %%
csv_result3 = csv_df3.head(10)
print("First 10 rows of the DataFrame:")
csv_result3
# Out:
# First 10 rows of the DataFrame:
#                   name   id nametype     recclass  mass (g)  fall    year  \
# 0               Aachen    1    Valid           L5      21.0  Fell  1880.0
# 1               Aarhus    2    Valid           H6     720.0  Fell  1951.0
# 2                 Abee    6    Valid          EH4  107000.0  Fell  1952.0
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0
# 4              Achiras  370    Valid           L6     780.0  Fell  1902.0
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell  1919.0
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell  1949.0
# 7                 Agen  392    Valid           H5   30000.0  Fell  1814.0
# 8               Aguada  398    Valid           L6    1620.0  Fell  1930.0
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell  1920.0
#
#      reclat    reclong           GeoLocation
# 0  50.77500    6.08333     (50.775, 6.08333)
# ...

# %% [markdown]
# # XLSX Dataset

# %%
import pandas as pd

# %% [markdown]
# ## XLSX Dataset **1**

# %%
xlsx_df1 = pd.read_excel("rxsummary2018.xlsx")
xlsx_df1
# Out:
#       YEAR RECORD_TYPE  NUMBER_SCRIPTS                              NPROPNAME  \
# 0     2018        Drug              58                       ABACAVIR SULFATE
# 1     2018        Drug             409                       ABACAVIR SULFATE
# 2     2018        Drug             261                       ABACAVIR SULFATE
# 3     2018        Drug             108            ABACAVIR SULFATE,LAMIVUDINE
# 4     2018        Drug             531            ABACAVIR SULFATE,LAMIVUDINE
# ...    ...         ...             ...                                    ...
# 3877  2018        Drug             504                    ZOSTER VACCINE LIVE
# 3878  2018        Drug              33                    ZOSTER VACCINE LIVE
# 3879  2018        Drug           28034  ZOSTER VACCINE RECOMBINANT ADJUVANTED
# 3880  2018        Drug           75631  ZOSTER VACCINE RECOMBINANT ADJUVANTED
# 3881  2018        Drug            3785  ZOSTER VACCINE RECOMBINANT ADJUVANTED
#
# ...

# %%
xlsx_result1 = xlsx_df1.head(10)
print("First 10 rows of the DataFrame:")
xlsx_result1
# Out:
# First 10 rows of the DataFrame:
#    YEAR RECORD_TYPE  NUMBER_SCRIPTS                         NPROPNAME  \
# 0  2018        Drug              58                  ABACAVIR SULFATE
# 1  2018        Drug             409                  ABACAVIR SULFATE
# 2  2018        Drug             261                  ABACAVIR SULFATE
# 3  2018        Drug             108       ABACAVIR SULFATE,LAMIVUDINE
# 4  2018        Drug             531       ABACAVIR SULFATE,LAMIVUDINE
# 5  2018        Drug             671       ABACAVIR SULFATE,LAMIVUDINE
# 6  2018        Drug            2767  ABACAVIR,DOLUTEGRAVIR,LAMIVUDINE
# 7  2018        Drug            2488  ABACAVIR,DOLUTEGRAVIR,LAMIVUDINE
# 8  2018        Drug            5377  ABACAVIR,DOLUTEGRAVIR,LAMIVUDINE
# 9  2018        Drug             527                     ABALOPARATIDE
#
#                       THER_CLASS                           PAYER  \
# 0          Anti-Infective Agents                      Commercial
# ...

# %% [markdown]
# ## XLSX Dataset 2

# %%
xlsx_df2 = pd.read_excel("utilization2019.xlsx")
xlsx_df2
# Out:
#        row_id  service_year  county_code county_name  \
# 0      198470          2019            3       Anoka
# 1      199334          2019            7    Beltrami
# 2      200414          2019           13  Blue Earth
# 3      201134          2019           17     Carlton
# 4      201854          2019           21        Cass
# ...       ...           ...          ...         ...
# 20848  225493          2019          151       Swift
# 20849  226645          2019          157     Wabasha
# 20850  227581          2019          163  Washington
# 20851  228325          2019          167      Wilkin
# 20852  229381          2019          171      Wright
#
#                                 payer  age_group_code      age_group_name sex  \
# 0      MINNESOTA HEALTH CARE PROGRAMS               3       45 - 64 years   M
# 1      MINNESOTA HEALTH CARE PROGRAMS               5  75 years and older   M
# 2      MINNESOTA HEALTH CARE PROGRAMS               4       65 - 74 years   F
# ...

# %%
xlsx_result2 = xlsx_df2.head(10)
print("First 10 rows of the DataFrame:")
xlsx_result2
# Out:
# First 10 rows of the DataFrame:
#    row_id  service_year  county_code county_name  \
# 0  198470          2019            3       Anoka
# 1  199334          2019            7    Beltrami
# 2  200414          2019           13  Blue Earth
# 3  201134          2019           17     Carlton
# 4  201854          2019           21        Cass
# 5  202766          2019           25     Chisago
# 6  203726          2019           31        Cook
# 7  204638          2019           35   Crow Wing
# 8  205286          2019           39       Dodge
# 9  206030          2019           43   Faribault
#
#                             payer  age_group_code      age_group_name sex  \
# 0  MINNESOTA HEALTH CARE PROGRAMS               3       45 - 64 years   M
# 1  MINNESOTA HEALTH CARE PROGRAMS               5  75 years and older   M
# 2  MINNESOTA HEALTH CARE PROGRAMS               4       65 - 74 years   F
# 3  MINNESOTA HEALTH CARE PROGRAMS               3       45 - 64 years   F
# ...

# %% [markdown]
# ## XLSX Dataset 3

# %%
xlsx_df3 = pd.read_excel("sampledatafoodinfo.xlsx")
xlsx_df3
# Out:
#          Category                                          Food Item Measure  \
# 0     Baked Goods                  Angelfood, commercial (25cm diam)    1/12
# 1     Baked Goods                    Angelfood, from mix (25cm diam)    1/12
# 2     Baked Goods            Animal crackers (arrowroot, social tea)       2
# 3     Baked Goods                              Apple crisp, homemade   125mL
# 4     Baked Goods             Apple, commercial, 2 crust (23cm diam)     1/8
# ...           ...                                                ...     ...
# 1089   Vegetables  Vegetables, broccoli and cauliflower, frozen, ...   125mL
# 1090   Vegetables  Vegetables, mixed (corn, lima beans, snap bean...   125mL
# 1091   Vegetables  Vegetables, peas and carrots, canned, not drained   125mL
# 1092   Vegetables                              Zucchini, raw, slices       4
# 1093   Vegetables                  Zucchini, sliced, boiled, drained   125mL
#
#       Calories  Protein   Fat  Carbs  Fibre
# ...

# %%
xlsx_result3 = xlsx_df3.head(10)
print("First 10 rows of the DataFrame:")
xlsx_result3
# Out:
# First 10 rows of the DataFrame:
#       Category                                         Food Item  Measure  \
# 0  Baked Goods                 Angelfood, commercial (25cm diam)     1/12
# 1  Baked Goods                   Angelfood, from mix (25cm diam)     1/12
# 2  Baked Goods           Animal crackers (arrowroot, social tea)        2
# 3  Baked Goods                             Apple crisp, homemade    125mL
# 4  Baked Goods            Apple, commercial, 2 crust (23cm diam)      1/8
# 5  Baked Goods              Apple, homemade, 2 crust (23cm diam)      1/8
# 6  Baked Goods         Banana bread, homemade (11cm X 6cm X 1cm)  1 slice
# 7  Baked Goods  Banana cream, from mix, no-bake type (23cm diam)      1/8
# 8  Baked Goods           Biscuit, plain or buttermilk, fast food        1
# 9  Baked Goods     Biscuit, plain or buttermilk, from mix, baked        1
#
#    Calories  Protein   Fat  Carbs  Fibre
# 0        73      2.0   NaN   16.0    0.4
# ...

# %% [markdown]
# # JSON Dataset

# %%
import pandas as pd
import json
import requests

# %% [markdown]
# ## JSON Dataset 1

# %%
json_df1 = pd.read_json("medicare_physician.json")

# %%
json_df1
# Out:
#      Rndrng_NPI Rndrng_Prvdr_Last_Org_Name Rndrng_Prvdr_First_Name  \
# 0    1003000126                  Enkeshafi                 Ardalan
# 1    1003000134                     Cibull                  Thomas
# 2    1003000142                     Khalil                  Rashid
# 3    1003000423                    Velotta                Jennifer
# 4    1003000480                  Rothchild                   Kevin
# ..          ...                        ...                     ...
# 995  1003059544                      Nagle                   Alana
# 996  1003059676                   Daruwala                  Cherag
# 997  1003059684                    Muthuri                    Leah
# 998  1003059783                       Szot                 Jeffrey
# 999  1003059866                      Ahsan                Shagufta
#
#     Rndrng_Prvdr_MI Rndrng_Prvdr_Crdntls Rndrng_Prvdr_Gndr  \
# 0                                   M.D.                 M
# ...

# %%
json_result1 = json_df1.head(10)
print("First 10 rows of the DataFrame:")
json_result1
# Out:
# First 10 rows of the DataFrame:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa
# 5          5.4         3.9          1.7         0.4  setosa
# 6          4.6         3.4          1.4         0.3  setosa
# 7          5.0         3.4          1.5         0.2  setosa
# 8          4.4         2.9          1.4         0.2  setosa
# 9          4.9         3.1          1.5         0.1  setosa

# %% [markdown]
# ## JSON Dataset 2

# %%
json_df2 = pd.read_json('medicare_outpatient.json')
json_df2
# Out:
#      Rndrng_Prvdr_CCN            Rndrng_Prvdr_Org_Name  \
# 0               10001  Southeast Health Medical Center
# 1               10001  Southeast Health Medical Center
# 2               10001  Southeast Health Medical Center
# 3               10001  Southeast Health Medical Center
# 4               10001  Southeast Health Medical Center
# ..                ...                              ...
# 995             10056          St Vincent's Birmingham
# 996             10056          St Vincent's Birmingham
# 997             10056          St Vincent's Birmingham
# 998             10056          St Vincent's Birmingham
# 999             10056          St Vincent's Birmingham
#
#             Rndrng_Prvdr_St Rndrng_Prvdr_City Rndrng_Prvdr_State_Abrvtn  \
# 0    1108 Ross Clark Circle            Dothan                        AL
# 1    1108 Ross Clark Circle            Dothan                        AL
# 2    1108 Ross Clark Circle            Dothan                        AL
# ...

# %%
json_result2 = json_df2.head(10)
print("First 10 rows of the DataFrame:")
json_result2
# Out:
# First 10 rows of the DataFrame:
#    Rndrng_Prvdr_CCN            Rndrng_Prvdr_Org_Name         Rndrng_Prvdr_St  \
# 0             10001  Southeast Health Medical Center  1108 Ross Clark Circle
# 1             10001  Southeast Health Medical Center  1108 Ross Clark Circle
# 2             10001  Southeast Health Medical Center  1108 Ross Clark Circle
# 3             10001  Southeast Health Medical Center  1108 Ross Clark Circle
# 4             10001  Southeast Health Medical Center  1108 Ross Clark Circle
# 5             10001  Southeast Health Medical Center  1108 Ross Clark Circle
# 6             10001  Southeast Health Medical Center  1108 Ross Clark Circle
# 7             10001  Southeast Health Medical Center  1108 Ross Clark Circle
# 8             10001  Southeast Health Medical Center  1108 Ross Clark Circle
# 9             10001  Southeast Health Medical Center  1108 Ross Clark Circle
#
#   Rndrng_Prvdr_City Rndrng_Prvdr_State_Abrvtn  Rndrng_Prvdr_State_FIPS  \
# ...

# %% [markdown]
# ## JSON Dataset 3

# %%
json_df3 = pd.read_json('medicare_inpatient.json')
json_df3
# Out:
#      Rndrng_Prvdr_CCN            Rndrng_Prvdr_Org_Name Rndrng_Prvdr_City  \
# 0               10001  Southeast Health Medical Center            Dothan
# 1               10001  Southeast Health Medical Center            Dothan
# 2               10001  Southeast Health Medical Center            Dothan
# 3               10001  Southeast Health Medical Center            Dothan
# 4               10001  Southeast Health Medical Center            Dothan
# ..                ...                              ...               ...
# 995             10039              Huntsville Hospital        Huntsville
# 996             10039              Huntsville Hospital        Huntsville
# 997             10039              Huntsville Hospital        Huntsville
# 998             10039              Huntsville Hospital        Huntsville
# 999             10039              Huntsville Hospital        Huntsville
#
#             Rndrng_Prvdr_St  Rndrng_Prvdr_State_FIPS  Rndrng_Prvdr_Zip5  \
# ...

# %%
json_result3 = json_df3.head(10)
print("First 10 rows of the DataFrame:")
json_result3
# Out:
# First 10 rows of the DataFrame:
#    Rndrng_Prvdr_CCN            Rndrng_Prvdr_Org_Name Rndrng_Prvdr_City  \
# 0             10001  Southeast Health Medical Center            Dothan
# 1             10001  Southeast Health Medical Center            Dothan
# 2             10001  Southeast Health Medical Center            Dothan
# 3             10001  Southeast Health Medical Center            Dothan
# 4             10001  Southeast Health Medical Center            Dothan
# 5             10001  Southeast Health Medical Center            Dothan
# 6             10001  Southeast Health Medical Center            Dothan
# 7             10001  Southeast Health Medical Center            Dothan
# 8             10001  Southeast Health Medical Center            Dothan
# 9             10001  Southeast Health Medical Center            Dothan
#
#           Rndrng_Prvdr_St  Rndrng_Prvdr_State_FIPS  Rndrng_Prvdr_Zip5  \
# 0  1108 Ross Clark Circle                        1              36301
# ...
